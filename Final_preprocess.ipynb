# %%
pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
import os
import PyPDF2
import pandas as pd

# Extract text from a PDF file
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ""
        for page_num in range(len(reader.pages)):
            page = reader.pages[page_num]
            text += page.extract_text()
    return text

# Find the line containing the "APPEAL NO." text
def find_appeal_text_in_pdf(text, search_string="APPEAL NO."):
    lines = text.splitlines()
    for line in lines:
        if search_string in line:
            return line.strip()
    return ""

# Extract "REPORTABLE" and "APPELLATE JURISDICTION" information from a PDF
def extract_info_from_pdf(text):
    reportable_found = "NO"
    appellate_line = ""

    lines = text.splitlines()
    for line in lines:
        if "REPORTABLE" in line:
            reportable_found = "YES"
        if "NON-REPORTABLE" in line:
            reportable_found = "NO"

        if "APPELLATE JURISDICTION" in line:
            appellate_line = line.strip()

    return reportable_found, appellate_line

# Find the line with maximum overlap with the filename
def find_max_overlap_line(text, filename):
    lines = text.splitlines()
    max_overlap = 0
    line_to_remove = ""

    for line in lines:
        overlap = len(os.path.commonprefix([line, filename]))
        if overlap > max_overlap:
            max_overlap = overlap
            line_to_remove = line

    return line_to_remove

# Remove a specific line from the extracted text
def remove_line_from_text(text, line_to_remove):
    return text.replace(line_to_remove, "")

# Process all PDF files in a directory
def process_pdfs(directory):
    data = []

    for filename in os.listdir(directory):
        if filename.lower().endswith('.pdf'):
            pdf_path = os.path.join(directory, filename)
            text = extract_text_from_pdf(pdf_path)

            # Find and store the "APPEAL NO." line
            appeal_text = find_appeal_text_in_pdf(text)

            # Extract "REPORTABLE" and "APPELLATE JURISDICTION" information
            reportable, appellate_line = extract_info_from_pdf(text)

            # Find the line with maximum overlap with the filename
            line_to_remove = find_max_overlap_line(text, filename)

            # Remove the identified line from the text
            if line_to_remove:
                text = remove_line_from_text(text, line_to_remove)

            # Save updated text to a new file
            updated_text_path = os.path.join(directory, f"{os.path.splitext(filename)[0]}.txt")
            with open(updated_text_path, 'w') as file:
                file.write(text)

            # Add data to the list
            data.append({
                'File Name': filename,
                'Reportable': reportable,
                'Appellate Jurisdiction Line': appellate_line,
                'Appeal Text': appeal_text
            })

    # Create a DataFrame and save it to an Excel file
    df = pd.DataFrame(data)
    df.to_excel('pdf_analysis_results.xlsx', index=False)

    # Print the DataFrame to the console
    print(df)

# Example usage
directory_path = '/content/drive/MyDrive/delete/judgment'
process_pdfs(directory_path)
# Out:
#                                            File Name Reportable  \
# 0  A_M_Mohan_vs_The_State_Rep_By_Sho_on_20_March_...        YES
# 1  Abdul_Jabbar_vs_The_State_Of_Haryana_on_5_Febr...        YES
#
#        Appellate Jurisdiction Line                         Appeal Text
# 0  CRIMINAL APPELLATE JURISDICTION  CRIMINAL APPEAL NO.        OF 2024
# 1  CRIMINAL APPELLATE JURISDICTION

# %% [markdown]
# # Preprocessing & noise removal on the .txt file

# %%
import os
import re
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

nltk.download('punkt')

# Paths
input_folder = "/content/drive/MyDrive/delete/judgment"  # Updated input folder containing .txt files
output_folder = "/content/drive/MyDrive/delete/judgment/preprocessed_judgments"

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Function to preprocess text
def preprocess_text(text):
    text = re.sub(r"\xa0", " ", text)
    text = [re.sub(r'[^a-zA-Z0-9.,)\-(/?\t ]', '', sentence) for sentence in text.split("\n")]
    text = [re.sub(r'(?<=[^0-9])/(?=[^0-9])', ' ', sentence) for sentence in text]
    text = [re.sub("\t+", " ", sentence) for sentence in text]
    text = [re.sub(" +", " ", sentence) for sentence in text]
    text = [re.sub("\.\.+", "", sentence) for sentence in text]
    text = [re.sub("\A ?", "", sentence) for sentence in text]
    text = [sentence for sentence in text if (len(sentence) != 1 and not re.fullmatch("(\d|\d\d|\d\d\d)", sentence))]
    text = [re.sub('\A\(?(\d|\d\d\d|\d\d|[a-zA-Z])(\.|\))\s?(?=[A-Z])', '\n', sentence) for sentence in text]
    text = [re.sub("\A\(([ivx]+)\)\s?(?=[a-zA-Z0-9])", '\n', sentence) for sentence in text]
    text = [sentence for sentence in text if not re.search(r"Indian Kanoon", sentence)]
    text = "\n".join(text)
    text = re.sub(r"[()[\]\"]", " ", text)  # removing ()[\]\"
    text = re.sub(r" no\.", " number", text)  # converting no., nos., co., ltd. to number, numbers, company, and limited
    text = re.sub(r" nos\.", " numbers", text)
    text = re.sub(r" co\.", " company", text)
    text = re.sub(r" ltd\.", " limited", text)

    # Remove multiple newlines
    text2 = []
    for index in range(len(text.splitlines())):
        if index > 0 and text.splitlines()[index] == '' and text.splitlines()[index - 1] == '':
            continue
        if index < len(text.splitlines()) - 1 and text.splitlines()[index + 1] != '' and text.splitlines()[index + 1][0] == '\n' and text.splitlines()[index] == '':
            continue
        text2.append(text.splitlines()[index])

    text = "\n".join(text2)

    # Ignore the text before JUDGMENT or ORDER
    lines = text.splitlines()
    start_idx = 0
    for i, line in enumerate(lines):
        if re.search(r"\A(ORDER|JUDGMENT|J U D G M E N T|O R D E R)", line):
            start_idx = i
            break

    # Start from the first occurrence of "ORDER" or "JUDGMENT"
    text = "\n".join(lines[start_idx:])

    sentences = sent_tokenize(text)
    sentences = [sentence.strip() for sentence in sentences]

    # Add a period to any sentence that does not end with one
    sentences = [sentence if sentence.endswith('.') else sentence + '.' for sentence in sentences]

    # Join sentences with a newline
    processed_text = "\n".join(sentences)

    # Check if the number of tokens is sufficient
    num_tokens = len(word_tokenize(processed_text))
    if num_tokens < 100:
        return None

    return processed_text

# Function to process .txt files
def process_txt_files(input_folder, output_folder):
    for filename in os.listdir(input_folder):
        if filename.endswith('.txt'):
            input_file_path = os.path.join(input_folder, filename)

            # Read the content of the txt file
            with open(input_file_path, 'r') as file:
                text = file.read()

            # Preprocess the text
            preprocessed_text = preprocess_text(text)
            #print(preprocessed_text)

            if preprocessed_text:
                # Save the preprocessed text to the output folder
                output_file_path = os.path.join(output_folder, filename)
                with open(output_file_path, 'w') as output_file:
                    output_file.write(preprocessed_text)
                print(f"Processed and saved: {filename}")
            else:
                print(f"Skipped {filename} due to insufficient token count.")

# Example usage
process_txt_files(input_folder, output_folder)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Processed and saved: A_M_Mohan_vs_The_State_Rep_By_Sho_on_20_March_2024.txt
# Processed and saved: Abdul_Jabbar_vs_The_State_Of_Haryana_on_5_February_2024.txt

# %% [markdown]
# #Finding the abbriviations in the documents

# %%
# Define paths
input_folder = "/content/drive/MyDrive/My Dataset/2024/preprocessed_judgments"  # Replace with your input folder path
output_file = "/content/pdf_analysis_results.xlsx"  # Replace with your output file path

# %%
import os
import re
import pandas as pd

# Function to find unique abbreviations in a text
def find_unique_abbreviations(text):
    patterns = [
        r'\b(?:[A-Z]\.){2,}',  # U.S.A., Ph.D.
        #r'\b[A-Z]{2,}\b',      # NASA, CEO
        r'\b[A-Z][a-z]*\.',    # Inc., Ltd., Co.
        r'\b[A-Z][a-z]+\.'     # Mr., Dr., Ms.
    ]

    combined_pattern = '|'.join(patterns)
    abbreviations = re.findall(combined_pattern, text)
    unique_abbreviations = set(abbreviations)

    return unique_abbreviations

# Function to process all text files and save the abbreviations in a DataFrame
def process_text_files(input_folder, output_file):
    data = []

    # Iterate through each file in the folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".txt"):
            file_path = os.path.join(input_folder, filename)

            # Read the content of the file
            with open(file_path, 'r', encoding='utf-8') as file:
                text = file.read()

            # Find unique abbreviations in the text
            abbreviations = find_unique_abbreviations(text)

            # Add the results to the data list
            data.append({
                "File Name": filename,
                "Abbreviations": ", ".join(abbreviations)
            })
            print(f"Processed and saved: {filename}")

    # Create a DataFrame from the data list
    df = pd.DataFrame(data)

    # Save the DataFrame to an Excel sheet
    df.to_excel(output_file, index=False)

# Process the text files and save the results
process_text_files(input_folder, output_file)

# %% [markdown]
# # Finding unique abbriviations

# %%
import pandas as pd

# Define paths
input_file = '/content/abbriviation list.xlsx'  # Replace with your input file path
output_file = 'output_file.xlsx'  # Replace with your output file path

# Read the Excel file into a DataFrame
df = pd.read_excel(input_file)

# Ensure the column containing abbreviations is a string
df['Abbreviations'] = df['Abbreviations'].astype(str)

# Combine all abbreviations into a single list
all_abbreviations = ' '.join(df['Abbreviations'].tolist())

# Split the abbreviations by delimiter (assuming comma or space as delimiter)
abbreviation_list = all_abbreviations.split(', ')  # Adjust the delimiter if necessary

# Remove duplicates by converting to a set and then back to a list
unique_abbreviations = list(set(abbreviation_list))

# Create a DataFrame for the unique abbreviations
unique_df = pd.DataFrame(unique_abbreviations, columns=['Unique Abbreviations'])

# Save the unique abbreviations to a new Excel file
unique_df.to_excel(output_file, index=False)

print(f"Unique abbreviations have been saved to {output_file}")
# Out:
# Unique abbreviations have been saved to output_file.xlsx

# %%
unique_df
# Out:
#       Unique Abbreviations
# 0                 Orchard.
# 1               Mussoorie.
# 2                 Tanjore.
# 3                  Speech.
# 4              B.V. T.D.R.
# ...                    ...
# 12208          Presidency.
# 12209         Sambamurthy.
# 12210             Sahitya.
# 12211               Nahri.
# 12212                 Dow.
#
# [12213 rows x 1 columns]

# %% [markdown]
# # Making sentence including abbriviations for folder+sentence and token count

# %%
import os
import re
import pandas as pd
import nltk

nltk.download('punkt')

def load_text(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read()

def save_text(file_path, text):
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(text)

def process_sentences(text, abbr_set):
    lines = text.splitlines()
    processed_lines = []
    current_sentence = ""
    in_sentence = False

    for i, line in enumerate(lines):
        line = line.strip()
        if not line:
            continue

        words = re.findall(r'\b\w+\b', line)
        if words:
            last_word = words[-1].upper()

            if (
                last_word in abbr_set or
                not line.endswith('.') or
                (line.endswith('No.') and i + 1 < len(lines) and re.match(r'^\d', lines[i + 1].strip()))
            ):
                current_sentence += " " + line
                in_sentence = True
            else:
                if in_sentence:
                    current_sentence += " " + line
                    processed_lines.append(current_sentence.strip())
                    current_sentence = ""
                    in_sentence = False
                else:
                    processed_lines.append(line.strip())
        else:
            if in_sentence:
                current_sentence += " " + line

    if current_sentence:
        processed_lines.append(current_sentence.strip())

    return "\n".join(processed_lines)

def count_tokens_sentences(text):
    sentences = nltk.sent_tokenize(text)
    tokens = nltk.word_tokenize(text)
    return len(tokens), len(sentences)

def process_files(input_folder, output_folder, abbr_set):
    # Ensure output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # DataFrame to store the count of tokens and sentences for each file
    data = []

    for file_name in os.listdir(input_folder):
        if file_name.endswith('.txt'):
            input_file_path = os.path.join(input_folder, file_name)
            output_file_path = os.path.join(output_folder, file_name)

            text = load_text(input_file_path)
            processed_text = process_sentences(text, abbr_set)
            save_text(output_file_path, processed_text)

            # Count tokens and sentences
            token_count, sentence_count = count_tokens_sentences(processed_text)

            # Append results to the data list
            data.append({
                'File Name': file_name,
                'Token Count': token_count,
                'Sentence Count': sentence_count
            })

            print(f"Processed and saved: {file_name}")

    # Convert data list to DataFrame and save as Excel or CSV
    df = pd.DataFrame(data)
    output_stats_file = os.path.join(output_folder, 'file_stats.xlsx')
    df.to_excel(output_stats_file, index=False)

    print(f"Token and sentence counts have been saved to {output_stats_file}")

# Example usage
abbreviation_file = '/content/unique abbriviation.xlsx'  # Replace with your file path
df_abbr = pd.read_excel(abbreviation_file)
abbreviations = set(df_abbr['Unique Abbreviations'].str.strip().str.upper())

input_folder = '/content/drive/MyDrive/My Dataset/preprocessed_judgments'  # Replace with your input folder path
output_folder = '/content/drive/MyDrive/My Dataset/preprocessed_judgments/Final_judgments'  # Replace with your output folder path

process_files(input_folder, output_folder, abbreviations)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Streaming output truncated to the last 5000 lines.
# Processed and saved: Birla_Institute_Of_Technology_vs_The_State_Of_Jharkhand_on_7_March_2019.txt
# Processed and saved: Bir_Singh_vs_Mukesh_Kumar_on_6_February_2019.txt
# Processed and saved: Bishambhar_Prasad_vs_M_S_Arfat_Petrochemicals_Private_on_20_April_2023.txt
# Processed and saved: Board_Of_Governors_In_Supersession_Of_vs_Priyambada_Sharma_on_17_October_2022.txt
# Processed and saved: Binay_Kumar_Dalei_vs_The_State_Of_Odisha_on_2_March_2022.txt
# Processed and saved: Biltu_Bhattacharya_vs_The_State_Of_West_Bengal_on_10_May_2022.txt
# Processed and saved: Biraji_Brijraji_vs_Surya_Pratap_And_Ors_on_3_November_2020.txt
# Processed and saved: Bikram_Chatterji_vs_Union_Of_India_on_29_June_2021.txt
# Processed and saved: Bina_Basak_And_Ors_vs_Sri_Bipul_Kanti_Basak_And_Ors_on_21_March_2024.txt
# Processed and saved: Dauvaram_Nirmalkar_vs_The_State_Of_Chhattisgarh_on_2_August_2022.txt
# Processed and saved: Dav_Public_School_vs_The_Senior_Manager_Indian_Bank_Midnapur_on_18_December_2019.txt
# Processed and saved: Daxaben_vs_The_State_Of_Gujarat_on_29_July_2022.txt
# Processed and saved: Damodhar_D_Thr_Lrs_vs_Tejrao_Bajirao_Mhaske_And_Ors_on_4_May_2023.txt
# Processed and saved: Darmendra_Kumar_Dhamma_vs_The_State_Of_Madhya_Pradesh_on_8_July_2024.txt
# Processed and saved: Dalpat_Singh_Naruka_vs_Karuna_Bansal_on_21_April_2022.txt
# Processed and saved: Dakshin_Haryana_Bijli_Vitran_Nigam_Ltd_vs_M_S_Navigant_Technologies_Pvt_Ltd_on_2_March_2021.txt
# Processed and saved: Dalbir_Singh_vs_State_Of_Nct_Of_Delhi_on_28_August_2020.txt
# Processed and saved: Dalbir_Singh_vs_Union_Of_India_on_2_July_2019.txt
# Processed and saved: Darshan_Singh_vs_The_State_Of_Punjab_Secretary_Rural_on_22_January_2021.txt
# Processed and saved: Dasanglu_Pul_vs_Lupalum_Kri_on_19_October_2023.txt
# Processed and saved: Darshan_Singh_vs_State_Of_Punjab_on_6_December_2019.txt
# Processed and saved: Darshan_Singh_vs_The_State_Of_Punjab_on_4_January_2024.txt
# Processed and saved: C_Yamini_vs_The_High_Court_For_The_State_Of_Andhra_on_23_February_2023.txt
# Processed and saved: C_S_Venkatesh_vs_A_S_C_Murthy_D_By_Lrs_on_7_February_2020.txt
# Processed and saved: C_M_D_City_Union_Bank_Limited_vs_R_Chandramohan_on_27_March_2023.txt
# Processed and saved: C_Shanmugavel_vs_Eswari_on_28_January_2019.txt
# Processed and saved: C_M_Kisan_Inter_College_Manager_vs_The_State_Of_Uttar_Pradesh_on_4_October_2019.txt
# Processed and saved: C_S_Gopalakrishnan_vs_The_State_Of_Tamil_Nadu_on_9_May_2023.txt
# Processed and saved: Dakkata_Balaram_Reddy_vs_The_State_Of_Andhra_Pradesh_on_21_April_2023.txt
# Processed and saved: Dablu_Kujur_vs_The_State_Of_Jharkhand_on_12_March_2024.txt
# Processed and saved: C_S_Ramaswamy_vs_V_K_Senthil_on_30_September_2022.txt
# Processed and saved: C_Haridasan_vs_Anappath_Parakkattu_Vasudevakurup_on_13_January_2023.txt
# Processed and saved: C_C_E_Vadodara_vs_Gujarat_Narmada_Valley_Fer_Co_Ltd_on_3_December_2019.txt
# Processed and saved: C_I_T_New_Delhi_vs_Ram_Kishan_Dass_on_26_March_2019.txt
# Processed and saved: C_Manjamma_vs_The_Divisional_Manager_on_29_March_2022.txt
# Processed and saved: C_C_C_E_And_S_T_Bangalore_vs_M_S_Northern_Operating_Systems_Pvt_on_19_May_2022.txt
# Processed and saved: Dahiben_vs_Arvindbhai_Kalyanji_Bhanusali_Gajra_on_9_July_2020.txt
# Processed and saved: C_I_T_Delhi_vs_Bharti_Hexacom_Ltd_on_16_October_2023.txt
# Processed and saved: Delhi_Airport_Metro_Express_Pvt_Ltd_vs_Delhi_Metro_Rail_Corporation_Ltd_on_9_September_2021.txt
# Processed and saved: Deepak_Yadav_vs_The_State_Of_Uttar_Pradesh_on_20_May_2022.txt
# Processed and saved: Deepak_vs_The_State_Of_Maharashtra_on_28_January_2022.txt
# Processed and saved: Deependra_Yadav_vs_State_Of_M_P_on_1_May_2024.txt
# Processed and saved: Deepak_Kumar_Shrivas_vs_State_Of_Chhattisgarh_on_19_February_2024.txt
# Processed and saved: Deepak_Chandrakant_Jhaveri_vs_Johnson_Dye_Works_P_Ltd_on_3_March_2020.txt
# Processed and saved: Deepa_Mohan_Naik_vs_Chandra_Bhusan_Pal_on_4_October_2021.txt
# Processed and saved: Delhi_Development_Authority_vs_Amit_Jain_on_24_February_2023.txt
# Processed and saved: Delhi_Commission_For_Protection_Of_vs_Union_Of_India_on_25_January_2022.txt
# Processed and saved: Delhi_Airport_Metro_Express_Private_vs_Delhi_Metro_Rail_Corporation_on_5_May_2022.txt
# Processed and saved: Deep_Mukerjee_vs_Sreyashi_Banerjee_on_5_April_2024.txt
# Processed and saved: Delhi_Development_Authority_Vice_vs_Shakuntla_Devi_on_20_January_2023.txt
# Processed and saved: Delhi_Dayalbagh_Cooperative_House_vs_Registrar_Cooperative_Societies_on_30_January_2019.txt
# Processed and saved: Delhi_Dayal_Bagh_House_Building_Society_vs_Regitrar_Co_Operative_Societies_on_30_January_2019.txt
# Processed and saved: Deep_Narayan_Chourasia_vs_The_State_Of_Bihar_on_25_February_2019.txt
# Processed and saved: Delhi_Administration_Thr_Secretary_vs_Pawan_Kumar_on_6_May_2022.txt
# Processed and saved: Deepak_Gaba_vs_State_Of_Uttar_Pradesh_on_2_January_2023.txt
# Processed and saved: Deepak_Ananda_Patil_vs_The_State_Of_Maharashtra_on_4_January_2023.txt
# Processed and saved: Deepak_Tandon_vs_Rajesh_Kumar_Gupta_on_7_February_2019.txt
# Processed and saved: Debidutta_Mohanty_vs_Ranjan_Kumar_Pattnaik_on_3_March_2023.txt
# Processed and saved: Deccan_Paper_Mills_Co_Ltd_vs_Regency_Mahavir_Properties_on_19_August_2020.txt
# Processed and saved: Dbs_Bank_Limited_Singapore_vs_Ruchi_Soya_Industries_Limited_on_3_January_2024.txt
# Processed and saved: Debasish_Paul_vs_Amal_Boral_on_18_October_2023.txt
# Processed and saved: Daya_Ram_vs_The_State_Of_Madhya_Pradesh_on_7_November_2019.txt
# Processed and saved: Deepika_Singh_vs_Central_Administrative_Tribunal_on_16_August_2022.txt
# Processed and saved: Deenadayal_Nagari_Sahakari_Bank_Ltd_vs_Munjaji_on_16_February_2022.txt
# Processed and saved: Debabrata_Saha_vs_Serampore_Municipality_And_Others_on_1_September_2021.txt
# Processed and saved: Debashis_Sinha_vs_M_S_R_N_R_Enterprise_on_9_February_2023.txt
# Processed and saved: Debananda_Tamuli_vs_Smti_Kakumoni_Kataky_on_15_February_2022.txt
# Processed and saved: Dayle_De_Souza_vs_Government_Of_India_Thr_Deputy_Chief_on_29_October_2021.txt
# Processed and saved: Devendra_Pathak_Sarvodaya_College_Of_vs_National_Council_For_Teacher_Education_on_11_August_2021.txt
# Processed and saved: Devender_Singh_vs_The_State_Of_Uttarakhand_on_21_April_2022.txt
# Processed and saved: Desh_Raj_vs_Rohtash_Singh_on_14_December_2022.txt
# Processed and saved: Devas_Multimedia_Private_Limited_vs_Antrix_Corporation_Limited_on_17_January_2022.txt
# Processed and saved: Developer_Group_India_Pvt_Ltd_vs_Surinder_Singh_Marwah_on_25_January_2023.txt
# Processed and saved: Desh_Raj_vs_Balkishan_D_Through_Proposed_Lr_Ms_on_20_January_2020.txt
# Processed and saved: Devadassan_vs_The_Second_Class_Executive_Magistrate__on_9_March_2022.txt
# Processed and saved: Devender_Bhaskar_vs_State_Of_Haryana_on_24_November_2021.txt
# Processed and saved: Department_Of_Customes_vs_Sharad_Gandhi_Proprietor_on_27_February_2019.txt
# Processed and saved: Desh_Deepak_Kumar_Vihangam_Deepak_vs_The_State_Of_Bihar_on_8_March_2022.txt
# Processed and saved: Deputy_Commissioner_Of_Income_Tax_vs_M_S_M_R_Shah_Logistics_Pvt_Ltd_on_28_March_2022.txt
# Processed and saved: Dental_Council_Of_India_vs_Sailendra_Sharma_on_21_October_2022.txt
# Processed and saved: Deputy_Commissioner_Of_Income_Tax_vs_M_S_Pepsi_Foods_Ltd_Now_Pepsico_India_on_6_April_2021.txt
# Processed and saved: Deputy_Executive_Engineer_vs_Kuberbhai_Kanjibhai_on_7_January_2019.txt
# Processed and saved: Deputy_Superintendent_Of_Police_vs_Ashoo_Surendranath_Tewari_on_8_September_2020.txt
# Processed and saved: Derha_vs_Vishal_on_1_September_2023.txt
# Processed and saved: Department_Of_Mines_And_Geology_State_Of_vs_State_Leave_Environment_Impact_on_18_November_2019.txt
# Processed and saved: Deputy_General_Manager_Appellate_vs_Ajai_Kumar_Srivastava_on_5_January_2021.txt
# Processed and saved: Dental_Council_Of_India_vs_Biyani_Shikshan_Samiti_on_12_April_2022.txt
# Processed and saved: Delhi_International_Airport_Ltd_vs_M_S_Airport_Economic_Regulatory_on_11_July_2022.txt
# Processed and saved: Delhi_Subordinate_Services_Selection_vs_Seema_Kapoor_on_22_July_2021.txt
# Processed and saved: Delhi_Metro_Rail_Corporation_Ltd_vs_Delhi_Airport_Metro_Express_Pvt_Ltd_on_10_April_2024.txt
# Processed and saved: Delhi_Transport_Corporation_Through_vs_Ashok_Kumar_Sharma_on_18_July_2024.txt
# Processed and saved: Delhi_Transport_Corporation_vs_Sandeep_Kaushik_on_3_August_2022.txt
# Processed and saved: Delma_Lubna_Coelho_vs_Edmond_Clint_Fernandes_on_18_April_2023.txt
# Processed and saved: Delhi_Jal_Board_vs_Nirmala_Devi_on_19_October_2022.txt
# ...
# Processed and saved: Velthepu_Srinivas_vs_State_Of_Andhra_Pradesh_Now_State_Of_on_6_February_2024.txt
# Processed and saved: Ved_vs_The_State_Of_Haryana_on_8_April_2021.txt
# Processed and saved: Vinay_Eknath_Lad_vs_Chiu_Mao_Chen_on_18_December_2019.txt
# Processed and saved: Vinodchandra_Sakarlal_Kapadia_vs_State_Of_Gujarat_on_15_June_2020.txt
# Processed and saved: Vinit_Garg_vs_University_Grants_Commission_on_29_August_2019.txt
# Processed and saved: Vikrant_Singh_Malik_vs_Supertech_Ltd_on_24_August_2020.txt
# Processed and saved: Vikram_Johar_vs_The_State_Of_Uttar_Pradesh_on_26_April_2019.txt
# Processed and saved: Vikas_Singh_vs_Govt_Of_Nct_Of_Delhi_on_11_August_2022.txt
# Processed and saved: Vikesh_Kumar_Gupta_vs_The_State_Of_Rajasthan_on_7_December_2020.txt
# Processed and saved: Vikas_Kanaujia_vs_Sarita_on_10_July_2024.txt
# Processed and saved: Vikrant_Kapila_vs_Pankaja_Panda_on_10_October_2023.txt
# Processed and saved: Vikramjit_Kakati_vs_The_State_Of_Assam_on_4_August_2022.txt
# Processed and saved: Vinayak_Purshottam_Dube_Deceased_vs_Jayashree_Padmakar_Bhat_on_1_March_2024.txt
# Processed and saved: Vikrant_Vikal_Tripathi_vs_The_State_Of_Uttar_Pradesh_Through_Its_on_28_September_2021.txt
# Processed and saved: Vinay_Kumar_Mittal_vs_Dewan_Housing_Finance_Corporation_Ltd_on_31_January_2020.txt
# Processed and saved: Vimla_Devi_vs_Chhabiram_on_16_November_2021.txt
# Processed and saved: Vineeta_Sharma_vs_Rakesh_Sharma_on_11_August_2020.txt
# Processed and saved: Vinay_Sharma_vs_Union_Of_India_on_14_February_2020.txt
# Processed and saved: Vikas_Kishanrao_Gawali_vs_The_State_Of_Maharashtra_on_4_March_2021.txt
# Processed and saved: Vikas_Rathi_vs_The_State_Of_Uttar_Pradesh_on_1_March_2023.txt
# Processed and saved: Vikas_Chaudhary_vs_The_State_Of_Delhi_on_21_April_2023.txt
# Processed and saved: Vikash_Kumar_vs_Union_Public_Service_Commission_on_11_February_2021.txt
# Processed and saved: Vijay_Pratap_Yadav_vs_The_State_Of_Uttar_Pradesh_on_23_February_2022.txt
# Processed and saved: Vijay_Pandey_vs_The_State_Of_Uttar_Pradesh_on_30_July_2019.txt
# Processed and saved: Vijay_Nathalal_Gohil_vs_The_State_Of_Maharashtra_on_3_September_2019.txt
# Processed and saved: Vijay_Rajmohan_vs_State_Represented_By_The_Inspector_Of_on_11_October_2022.txt
# Processed and saved: Vijay_vs_Union_Of_India_on_29_November_2023.txt
# Processed and saved: Vijay_Mohan_Singh_vs_State_Of_Karnataka_on_10_April_2019.txt
# Processed and saved: Vijay_vs_The_State_Of_Madhya_Pradesh_on_11_January_2023.txt
# Processed and saved: Vijendra_vs_The_State_Of_Uttar_Pradesh_on_31_July_2019.txt
# Processed and saved: Vijay_Madanlal_Choudhary_vs_Union_Of_India_on_27_July_2022.txt
# Processed and saved: Vijay_Kumar_Ghai_vs_The_State_Of_West_Bengal_on_26_April_2023.txt
# Processed and saved: Vijay_Kumar_Jain_vs_Standard_Chartered_Bank_on_31_January_2019.txt
# Processed and saved: Vijay_A_Mittal_vs_Kulwant_Rai_Dead_Thr_Lrs_on_28_January_2019.txt
# Processed and saved: Vijay_Hathising_Shah_vs_Gitaben_Parshottamdas_Mukhi_on_25_February_2019.txt
# Processed and saved: Vijay_Kumar_Ghai_vs_The_State_Of_West_Bengal_on_22_March_2022.txt
# Processed and saved: Vijay_Kumar_Goyal_Dead_Thr_Lr_vs_Neena_Rani_on_16_September_2022.txt
# Processed and saved: Vijay_Raikwar_vs_The_State_Of_Madhya_Pradesh_on_5_February_2019.txt
# Processed and saved: Vijay_Karia_vs_Prysmian_Cavi_E_Sistemi_Srl_on_13_February_2020.txt
# Processed and saved: Vithaldas_Jagannath_Khatri_D_Through_vs_The_State_Of_Maharashtra_Revenue_And_on_19_February_2020.txt
# Processed and saved: Vishnu_Kumar_Tiwari_vs_The_State_Of_Uttar_Pradesh_on_9_July_2019.txt
# Processed and saved: Vishwanatha_vs_The_State_Of_Karnataka_State_Of_on_8_July_2024.txt
# Processed and saved: Vishwas_Bhandari_vs_The_State_Of_Punjab_on_3_February_2021.txt
# Processed and saved: Vishwabandhu_vs_Sri_Krishna_on_29_September_2021.txt
# Processed and saved: Vishal_Tiwari_vs_Union_Of_India_on_3_January_2024.txt
# Processed and saved: Vishram_Varu_And_Co_vs_Union_Of_India_on_21_April_2022.txt
# Processed and saved: Vishal_Tiwari_vs_Union_Of_India_on_2_March_2023.txt
# Processed and saved: Vishal_Vijay_Kalantri_vs_Shailen_Shah_Resolution_Professional_on_4_May_2022.txt
# Processed and saved: Vishnu_Kumar_Shukla_vs_The_State_Of_Uttar_Pradesh_on_28_November_2023.txt
# Processed and saved: Viram_Virma_vs_The_State_Of_Madhya_Pradesh_on_23_November_2021.txt
# Processed and saved: Virender_vs_State_Of_Haryana_on_16_December_2019.txt
# Processed and saved: Vishal_Ashwin_Patel_vs_Assistant_Commissioner_Of_Income_Tax_on_28_March_2022.txt
# Processed and saved: Virendrasing_vs_The_Additional_Commissioner_on_17_April_2023.txt
# Processed and saved: Vishal_Ashok_Thorat_vs_Rajesh_Shrirambapu_Fate_on_19_July_2019.txt
# Processed and saved: Virudhunagar_Hindu_Nadargal_Dharma_vs_Tuticorin_Educational_Society_on_3_October_2019.txt
# Processed and saved: Virendra_vs_The_State_Of_M_P_on_11_July_2022.txt
# Processed and saved: Virendra_Kumar_Chamar_vs_The_State_Of_Uttar_Pradesh_on_7_August_2024.txt
# Processed and saved: Viraj_Tra_Desai_vs_State_Of_Gujarat_on_30_August_2022.txt
# Processed and saved: Vishalakshi_Amma_vs_The_State_Of_Kerala_on_17_March_2023.txt
# Processed and saved: Vinubhai_Haribhai_Malaviya_vs_The_State_Of_Gujarat_on_16_October_2019.txt
# Processed and saved: Vinod_Kumar_vs_Ashok_Kumar_Gandhi_on_5_August_2019.txt
# Processed and saved: Vinod_Singh_Negi_vs_The_State_Of_Uttar_Pradesh_on_14_August_2019.txt
# Processed and saved: Vipin_Sahni_vs_Central_Bureau_Of_Investigation_Cbi_on_8_April_2024.txt
# Processed and saved: Vinod_Kumar_Sachdeva_Dead_Thr_Lrs_vs_Ashok_Kumar_Sachdeva_on_25_July_2023.txt
# Processed and saved: Vipan_Kumar_Dhir_vs_The_State_Of_Punjab_on_4_October_2021.txt
# Processed and saved: Vinod_Kumar_vs_Amritpal_Chhotu_on_30_November_2021.txt
# Processed and saved: Vinod_Verma_vs_Union_Of_India_And_Ors_on_2_April_2019.txt
# Processed and saved: Vinod_Ravjibhai_Rajput_vs_State_Of_Gujarat_on_14_February_2020.txt
# Processed and saved: Vinod_Kumar_vs_District_Magistrate_Mau_on_7_July_2023.txt
# Processed and saved: Vinod_Katara_vs_The_State_Of_Uttar_Pradesh_on_12_September_2022.txt
# Processed and saved: Vinod_Gupta_vs_The_State_Of_Madhya_Pradesh_on_6_March_2024.txt
# Processed and saved: Vinod_Jain_vs_Santokba_Durlabhji_Memorial_Hospital_on_25_February_2019.txt
# Processed and saved: Vinod_Bhaiyalal_Jain_vs_Wadhwani_Parmeshwari_Cold_Storage_on_24_July_2019.txt
# Processed and saved: Vinod_Giri_Goswami_vs_The_State_Of_Uttarakhand_on_14_February_2020.txt
# Processed and saved: Vinod_Jaswantray_Vyas_Dead_Through_vs_The_State_Of_Gujarat_on_9_July_2024.txt
# Processed and saved: Vinod_Katara_vs_The_State_Of_Uttar_Pradesh_on_5_March_2024.txt
# Processed and saved: Vinod_Kumar_Garg_vs_State_Govt_Of_National_Capi_T_Of_Delh_on_27_November_2019.txt
# Processed and saved: Vinod_Dua_vs_Union_Of_India_on_3_June_2021.txt
# Processed and saved: Vinod_Kanjibhai_Bhagora_vs_The_State_Of_Gujarat_on_2_February_2024.txt
# Processed and saved: Wazir_Khan_vs_The_State_Of_Uttarakhand_on_2_August_2023.txt
# Processed and saved: Waqf_Board_Rajasthan_vs_Jindal_Saw_Limited_on_29_April_2022.txt
# Processed and saved: Wasim_vs_State_Nct_Of_Delhi_on_18_July_2019.txt
# Processed and saved: Walaiti_Ram_Charan_Dass_vs_State_Of_Punjab_on_16_October_2019.txt
# Processed and saved: V_Senthil_Balaji_vs_The_State_Represented_By_Deputy_on_7_August_2023.txt
# Processed and saved: V_S_Ramakrishnan_vs_P_M_Muhammed_Ali_on_9_November_2022.txt
# Processed and saved: V_R_Sanal_Kumar_vs_Union_Of_India_on_12_May_2023.txt
# Processed and saved: Wainganga_Bahuddeshiya_Vikas_Sanstha_vs_Ku_Jaya_on_9_August_2019.txt
# Processed and saved: Wahab_Uddin_vs_Km_Meenakshi_Gahlot_on_13_November_2021.txt
# Processed and saved: Waheed_Ur_Rehman_Parra_vs_Union_Territory_Of_Jammu_And_Kashmir_on_25_February_2022.txt
# Processed and saved: Wazir_vs_The_State_Of_Haryana_on_11_January_2019.txt
# Processed and saved: V_Surendra_Mohan_vs_State_Of_Tamil_Nadu_on_22_January_2019.txt
# Processed and saved: V_Sukumaran_vs_State_Of_Kerala_on_26_August_2020.txt
# Processed and saved: V_Sreenivasa_Reddy_vs_B_L_Rathnamma_on_8_April_2021.txt
# Processed and saved: V_Senthur_vs_M_Vijayakumar_Ias_Secretary_Tamil_on_1_October_2021.txt
# Processed and saved: V_Prakash_G_N_V_Prakash_vs_M_S_P_S_Govindaswamy_Naidu_And_Sons_on_9_May_2022.txt
# Processed and saved: V_Nagarajan_vs_Sks_Ispat_And_Power_Limited_on_22_October_2021.txt
# Processed and saved: V_Prabhakara_vs_Basavaraj_K_Dead_By_Lr_on_7_October_2021.txt
# Processed and saved: V_Krishnamurthy_And_Anr_vs_State_Of_Tamil_Nadu_And_Ors_on_26_March_2019.txt
# Processed and saved: V_Kalyanaswamy_D_By_Lrs_vs_L_Bakthavatsalam_D_Thr_Lrs_on_17_July_2020.txt
# Processed and saved: V_N_Krishna_Murthy_vs_Sri_Ravikumar_on_21_August_2020.txt
# Processed and saved: V_Rajaram_vs_State_Represented_By_The_Inspector_Of_on_26_November_2019.txt
# Processed and saved: V_N_Patil_vs_K_Niranjan_Kumar_on_4_March_2021.txt
# Processed and saved: V_G_Jagdishan_vs_M_S_Indfos_Industries_Private_Limited_on_19_April_2022.txt
# Processed and saved: V_N_Public_Health_And_Educational_vs_State_Of_Kerala_And_Ors_Etc_on_24_February_2021.txt
# Processed and saved: Vivek_Narayan_Sharma_vs_Union_Of_India_on_2_January_2023.txt
# Processed and saved: Vodafone_Idea_Ltd_Earlier_Known_As_vs_Assistant_Commissioner_Of_Income_Tax_on_29_April_2020.txt
# Processed and saved: Vodafone_Essar_Cellular_Ltd_vs_Assistant_Commissioner_Of_Income_Tax_on_29_September_2021.txt
# Processed and saved: Vundavalli_Ratna_Manikyam_W_O_V_Rama_vs_V_P_P_R_N_Prasada_Rao_on_6_February_2020.txt
# Processed and saved: Vithaldas_Jagannath_Khatri_D_Through_vs_The_State_Of_Maharashtra_Revenue_And_on_29_August_2019.txt
# Processed and saved: V_Anantha_Raju_vs_T_M_Narasimhan_on_26_October_2021.txt
# Processed and saved: Vst_Industries_Limited_vs_The_State_Of_Uttar_Pradesh_on_22_April_2019.txt
# Processed and saved: Vitthalrao_Marotirao_Navkhare_vs_Nanibai_Dead_Thr_Lrs_on_8_April_2024.txt
# Processed and saved: Vithal_vs_State_Of_Karnataka_on_30_January_2024.txt
# Processed and saved: Vivek_Kaisth_vs_The_State_Of_Himachal_Pradesh_on_20_November_2023.txt
# Processed and saved: Yash_Developers_vs_Harihar_Krupa_Co_Operative_Housing_on_30_July_2024.txt
# Processed and saved: Yashita_Sahu_vs_The_State_Of_Rajasthan_on_20_January_2020.txt
# Processed and saved: Yashoda_Alias_Sodhan_vs_Sukhwinder_Singh_on_12_September_2022.txt
# Processed and saved: Yashpal_Singh_vs_The_State_Of_Uttar_Pradesh_on_15_September_2022.txt
# Processed and saved: X_vs_Y_on_8_July_2024.txt
# Processed and saved: Yadaiah_vs_The_State_Of_Telangana_on_1_August_2023.txt
# Processed and saved: Yashodhan_Singh_vs_The_State_Of_Uttar_Pradesh_on_18_July_2023.txt
# Processed and saved: Yamal_Manojbhai_vs_Union_Of_India_on_4_May_2023.txt
# Processed and saved: Yagwati_Poonam_vs_Ghanshyam_on_29_January_2024.txt
# Processed and saved: Yashpal_Jain_vs_Sushila_Devi_on_20_October_2023.txt
# Processed and saved: Xxx_vs_Union_Territory_Of_Andaman_And_Nicobar_on_24_August_2023.txt
# Processed and saved: X_vs_Union_Of_India_on_16_October_2023.txt
# Processed and saved: X_vs_The_Principal_Secretary_Health_And_on_29_September_2022.txt
# Processed and saved: X_vs_A_on_18_March_2024.txt
# Processed and saved: Wonder_Projects_Development_Pvt_Ltd_vs_Union_Of_India_on_11_August_2020.txt
# Processed and saved: Yamuna_Expressway_Industrial_vs_M_S_Shakuntla_Education_And_Welfare_on_19_May_2022.txt
# Processed and saved: W_N_Allal_Sundaram_vs_Commissioner_H_R_on_22_November_2019.txt
# Processed and saved: Wg_Cdr_A_U_Tayyaba_Retd_vs_Union_Of_India_on_15_April_2024.txt
# Processed and saved: X_vs_The_Principal_Secretary_Health_And_on_21_July_2022.txt
# Processed and saved: Willian_Stephen_vs_The_State_Of_Tamil_Nadu_And_Anr_on_21_February_2024.txt
# Processed and saved: West_U_P_Sugar_Mills_Association_vs_The_State_Of_Uttar_Pradesh_on_22_April_2020.txt
# Processed and saved: We_The_Women_Of_India_vs_Union_Of_India_on_18_August_2023.txt
# Processed and saved: We_The_Women_Of_India_vs_Union_Of_India_on_19_October_2023.txt
# Processed and saved: Welspun_Specialty_Solutions_Limited_vs_Oil_And_Natural_Gas_Corporation_Ltd_on_13_November_2021.txt
# Processed and saved: West_Bengal_Central_School_Service_vs_Abdul_Halim_on_24_July_2019.txt
# Processed and saved: West_Bengal_State_Electricity_vs_M_S_Orion_Metal_Pvt_Ltd_on_21_August_2019.txt
# Processed and saved: Westinghouse_Saxby_Farmer_Ltd_vs_Commr_Of_Central_Excise_Calcutta_on_8_March_2021.txt
# Processed and saved: X_vs_Registrar_General_on_10_February_2022.txt
# Processed and saved: Wg_Cdr_Arifur_Rahman_Khan_And_Aleya_vs_Dlf_Southern_Homes_Pvt_Ltd_Now_Known_on_24_August_2020.txt
# Processed and saved: West_Bengal_Small_Industries_vs_M_S_Sona_Promoters_Pvt_Ltd_And_Others_on_18_March_2020.txt
# Processed and saved: Western_Coalfields_Ltd_vs_Commissioner_Of_Central_Excise_Madurai_on_20_February_2019.txt
# Processed and saved: Weatherford_Oil_Tool_Middle_East_vs_Baker_Hughes_Singapore_Pte_on_20_October_2022.txt
# Processed and saved: Warad_Murti_Mishra_vs_The_State_Of_Madhya_Pradesh_on_15_June_2020.txt
# Processed and saved: Walchandnagar_Industries_Ltd_vs_The_State_Of_Maharashtra_on_4_February_2022.txt
# Processed and saved: Wave_Industries_Pvt_Ltd_vs_State_Of_U_P_on_15_December_2022.txt
# Processed and saved: Wapcos_Ltd_vs_Salma_Dam_Joint_Venture_on_14_November_2019.txt
# Processed and saved: Zonal_Manager_Bank_Of_India_Zonal_vs_Aarya_K_Babu_on_8_August_2019.txt
# Processed and saved: Zakia_Ahsan_Jafri_vs_The_State_Of_Gujarat_on_24_June_2022.txt
# Processed and saved: Zenith_Drugs_And_Allied_Agencies_Pvt_vs_M_S_Nicholas_Piramal_India_Ltd_on_30_July_2019.txt
# Processed and saved: Y_Savarimuthu_vs_The_State_Of_Tamil_Nadu_on_30_April_2019.txt
# Processed and saved: Zakir_Abdul_Mirajkar_vs_The_State_Of_Maharashtra_on_24_August_2022.txt
# Processed and saved: Y_Balaji_vs_Karthik_Desari_on_16_May_2023.txt
# Processed and saved: Yuvraj_Munna_Prahlad_Jagdale_vs_Janardan_Subajirao_Wide_Dead_on_21_March_2023.txt
# Processed and saved: Y_Sathiraju_D_Tr_His_Lrs_vs_Goli_Kannayya_Dead_By_Lrs_on_26_April_2019.txt
# Processed and saved: Y_Sai_Satya_Prasad_vs_D_Prabhakara_Rao_on_11_October_2022.txt
# Processed and saved: Zarifuddin_vs_Abdul_Qadir_on_20_September_2021.txt
# Processed and saved: Yusuf_Asif_vs_State_on_13_October_2023.txt
# Processed and saved: Yogesh_Upadhyay_vs_Atlanta_Limited_on_21_February_2023.txt
# Processed and saved: Yogesh_vs_The_State_Of_Haryana_on_6_April_2021.txt
# Processed and saved: Yogesh_Goyanka_vs_Govind_on_10_July_2024.txt
# Processed and saved: Yugal_Sikri_vs_State_Of_U_P_on_30_July_2024.txt
# Processed and saved: Y_P_Lele_vs_Maharashtra_State_Electricity_on_16_August_2023.txt
# Processed and saved: Yogesh_Navinchandra_Ravani_vs_Nanjibhai_Sagrambhai_Chaudhary_on_25_April_2023.txt
# Processed and saved: Yogesh_Sonu_vs_The_State_on_4_April_2024.txt
# Processed and saved: Yogendra_Prasad_Singh_Dead_Thr_Lrs_vs_Ram_Bachan_Devi_And_Ors_on_31_July_2023.txt
# Processed and saved: Yum_Restaurants_Market_Pvt_Ltd_vs_C_I_T_New_Delhi_on_24_April_2020.txt
# Processed and saved: Yogesh_Nagraoji_Ugale_vs_State_Of_Maharashtra_Through_Principal_on_26_August_2019.txt
# Processed and saved: Yatinder_Kumar_Aggarwal_vs_Mukund_Swarup_on_22_January_2019.txt
# Processed and saved: Yatinkumar_Jasubhai_Patel_vs_State_Of_Gujarat_on_4_October_2019.txt
# Processed and saved: Yedala_Subba_Rao_vs_Union_Of_India_on_17_April_2023.txt
# Processed and saved: Yatin_Narendra_Oza_vs_High_Court_Of_Gujarat_on_28_October_2021.txt
# Processed and saved: Yash_Tuteja_vs_Union_Of_India_on_8_April_2024.txt
# Processed and saved: Yashwant_Sinha_vs_Central_Bureau_Of_Investigation_on_14_November_2019.txt
# Processed and saved: Yash_Raj_Films_Private_Limited_vs_Afreen_Fatima_Zaidi_on_22_April_2024.txt
# Processed and saved: Yashpal_Singh_vs_The_State_Of_Uttar_Pradesh_on_28_March_2023.txt
# Processed and saved: Yogendra_Jogendra_Singh_vs_The_State_Of_Madhya_Pradesh_on_17_January_2019.txt
# Token and sentence counts have been saved to /content/drive/MyDrive/My Dataset/preprocessed_judgments/Final_judgments/file_stats.xlsx
